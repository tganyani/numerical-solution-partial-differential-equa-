# %%
import numpy as np 
import matplotlib.pyplot  as plt

# %% [markdown]
# решение уравнения Лапласа
# $
# \\
# \Delta U = 0
# $

# %% [markdown]
# $
# U(-1,y) = 1-y^2 , \space U(1,y)=1-y^2 , \space \space \space U(x,-1) = x^2-1 , \space U(x,1)= x^2-1 , \space (x,y) \in [-1,1]\times[-1,1]
# $

# %% [markdown]
# точное решение
# $
# U(x,y) = x^2 - y^2
# $

# %% [markdown]
# $
# \Delta =  \frac{d^2 U}{dx^2} + \frac{d^2 U}{dy^2} = 0 \\
# = \frac{U_{i+1,j} -2U_{i,j}+U_{i-1,j} }{{\Delta x}^2} +  \frac{U_{i,j+1} -2U_{i,j}+U_{i,j-1} }{{\Delta y}^2} =0 \\
# U_{i,j} = \frac{U_{i+1,j}+U_{i-1,j}+U_{i,j+1}+U_{i,j-1}}{4}, \space \space \space \space \Delta x =\Delta y
# $

# %% [markdown]
# По метод Якобы
# $
# U_{i,j}^{n+1} = \frac{U_{i+1,j}^n+U_{i-1,j}^n+U_{i,j+1}^n+U_{i,j-1}^n}{4}
# $

# %%
f = lambda x,y :x**2 - y**2

# %%
def Yakob_Iteration_To_Laplace_Equation(n):
    x = np.linspace(-1,1,n)
    y = np.linspace(-1,1,n)
    X,Y = np.meshgrid(x,y)
    Z = f(X,Y)
    Z[1:-1,1:-1]=0
    while np.linalg.norm(np.ravel(f(X,Y)-Z))>1e-5:
        for i in range(1,n-1):
            for j in range(1,n-1):
                Z[i,j]= (1/4)*(Z[i,j-1] +Z[i,j+1]+Z[i-1,j]+Z[i+1,j])
    return X,Y,Z

# %%
R = Yakob_Iteration_To_Laplace_Equation(6)

# %%
fig = plt.figure(figsize=(14, 8))
ax = plt.axes(projection='3d')
ax.plot_surface(R[0], R[1], R[2], rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('$n=6$');

# %%
R = Yakob_Iteration_To_Laplace_Equation(12)
fig = plt.figure(figsize=(14, 8))
ax = plt.axes(projection='3d')
ax.plot_surface(R[0], R[1], R[2], rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('$n=12$');

# %%
R = Yakob_Iteration_To_Laplace_Equation(60)
fig = plt.figure(figsize=(14, 8))
ax = plt.axes(projection='3d')
ax.plot_surface(R[0], R[1], R[2], rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('$n=60$');

# %%
R = Yakob_Iteration_To_Laplace_Equation(80)
fig = plt.figure(figsize=(14, 8))
ax = plt.axes(projection='3d')
ax.plot_surface(R[0], R[1], R[2], rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('$n=80$');

# %%
def Error(N):
    n= len(N)
    E = np.zeros(n)
    for i in range(n):
        R=Yakob_Iteration_To_Laplace_Equation(N[i])
        W=f(R[0],R[1])
        e=np.linalg.norm(np.ravel(W-R[2]))/(np.linalg.norm(np.ravel(W)))
        E[i]=e
    return E

# %%
N =np.array([8,12,20,26,36,49,64,81])
E=Error(N)
E
# Out:
# array([1.44953846e-06, 1.42998228e-06, 1.03975437e-06, 8.37955807e-07,
#        6.21977705e-07, 4.61086975e-07, 3.58409578e-07, 2.85176938e-07])

# %%
plt.plot(N,E)
plt.xlabel('$N $')
plt.ylabel('$E $')
# Out:
# Text(0, 0.5, '$E $')
